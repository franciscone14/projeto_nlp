# %%
import pandas as pd
import re
import spacy

import nltk
nltk.download('stopwords')

from franc_lib import lexical


normalizer = lexical.Preprocessing()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/igorecarvalho/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
dataframe = pd.read_csv('dados.csv')

# %%
text = dataframe[dataframe['Unnamed: 0'] == 2]['text']

# %%
# ([^rs])  - Qualquer letra que não r ou s
# (?=\1+)  - Que se repita uma vez ou mais
# |(rr)    - Ou dois r's
# (?=r+)   - Que tenham mais r's à frente
# |(ss)    - Ou dois s's
# (?=s+)   - Que tenham mais s's à frente
regex = r"([^rs])(?=\1+)|(rr)(?=r+)|(ss)(?=s+)"

def remove_username(tweet):
    return re.sub('@[^\s]+',' ',tweet)

def remove_end_of_line(tweet):
    return tweet.replace('\n', ' ').replace('RT', ' ')

def remove_duplicate_letters(tweet):
    tweet = re.sub(regex, '', tweet, 0)
    return tweet

# %%
dataframe.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1142208313532342274
# 1           1  1142208269513089024
# 2           2  1142208264861626370
# 3           3  1142208231558864896
# 4           4  1142208138520776704
#
#                                                 text
# 0                     Nossa putaria é quase um poema
# 1  ManooooKKKKKKKKK apareceu aqueles vídeos de li...
# 2  @felipesimoncini É putaria né ? Aqui no dique ...
# 3  acabei de fazer um Tinder pra minha tia e fale...
# 4  RT @MiiEDB: Queria viver um romance porém esta...

# %%
def normalize(tweet):
    tweet = remove_username(tweet)
    tweet = remove_end_of_line(tweet)
    tweet = remove_duplicate_letters(tweet)
    tweet = normalizer.lowercase(tweet)
    tweet = normalizer.remove_punctuation(tweet)
    tokens = normalizer.tokenize_words(tweet)
#     tokens = [token for token in tokens if token not in english_stopwords]
    return ' '.join(tokens)

# %%
dataframe['normalize'] = dataframe['text'].apply(normalize)

# %%
dataframe.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1142208313532342274
# 1           1  1142208269513089024
# 2           2  1142208264861626370
# 3           3  1142208231558864896
# 4           4  1142208138520776704
#
#                                                 text  \
# 0                     Nossa putaria é quase um poema
# 1  ManooooKKKKKKKKK apareceu aqueles vídeos de li...
# 2  @felipesimoncini É putaria né ? Aqui no dique ...
# 3  acabei de fazer um Tinder pra minha tia e fale...
# 4  RT @MiiEDB: Queria viver um romance porém esta...
#
#                                            normalize
# 0                     nossa putaria é quase um poema
# 1  manok apareceu aqueles vídeos de ligações do b...
# 2  é putaria né aqui no dique é frenquentar nos a...
# 3  acabei de fazer um tinder pra minha tia e fale...
# 4  queria viver um romance porém estamos no sécul...

# %%
hate_certeiras = [
    'feminazi','gayzista', 'viadismo', 'homossexualismo', 'viadagem', 'gayzismo', 'favelado',
    'gayzinho', 'sapatona', 'sapatão', 'bixa', 'verme', 'negrice', 'negrisse', 'negraiada','abortistas',
    'rameira', 'crioula', 'crioulas', 'crioulos', 'crioulo','tições', 'sangues ruins', 'bambis', 'boiola',
    'bichona', 'biba', 'traveco', 'viadinho', 'bichinha'
]

hate_verbo = [
    'matar', 'exterminar', 'odiar', 'queimar', 'atirar', 'esfaquear', 'bater', 'apanhar', 'roubar',
    'estuprar', 'ser', 'comer',
]

hate_adj = [
    'safado','imbecil', 'imbecis', 'cachaceiro', 'babaca', 'idiota', 'puta', 'puto', 'arrombado','arrombada',
    'canalha', 'vagabundo', 'vagabunda','burra', 'burro', 'maldito', 'maldita', 'neguim', 'neguinho', 
    'favelados', 'faveladas', 'favelada', 'maconheiro', 'maconhero', 'viado', 'viadinho', 'bichinha', 'lixo'
]

hate_words = [
    'putaria','bosta','cuzao', 'fdp', 'filho da puta',
    'merda', 'escroto', 'transfobia', 'gordo', 'canalha',
    'ditadura','gorda'
]

# %%
# Modelo ja baixado
# import subprocess
# command = "python3 -m spacy download pt_core_news_sm".split()
# subprocess.call(command)

nlp = spacy.load('models/pt_core_news_sm-2.1.0')

def tag(tweet):
    for hate in hate_certeiras:
        if hate in tweet:
            return 'hate'
    
    doc = nlp(tweet)
    
    for token in doc:
        if token.pos_ in ['VERB', 'AUX', 'DET', 'NOUN']:
            if token.lemma_ in hate_verbo:
                for hate in hate_adj:
                    if hate in tweet:
                        return 'hate'
                for hate in hate_words:
                    if hate in tweet:
                        return 'hate'
            elif token.lemma_ in hate_adj:
                return 'hate'
    return '-'

# %%
dataframe['tag'] = dataframe['normalize'].apply(tag)

# %%
dataframe.head(100)
# Out:
#     Unnamed: 0                   id  \
# 0            0  1142208313532342274
# 1            1  1142208269513089024
# 2            2  1142208264861626370
# 3            3  1142208231558864896
# 4            4  1142208138520776704
# 5            5  1142208053938458624
# 6            6  1142208016080670720
# 7            7  1142207999030771712
# 8            8  1142207991350996994
# 9            9  1142207977346293766
# 10          10  1142207883561582594
# 11          11  1142207883418984448
# 12          12  1142207864393687040
# 13          13  1142207817199378433
# 14          14  1142207789479186432
# 15          15  1142207725839011841
# 16          16  1142207681056378880
# 17          17  1142207674647494660
# 18          18  1142207571153100800
# 19          19  1142207508049780737
# 20          20  1142207265392549888
# 21          21  1142207156936216577
# 22          22  1142207151777210369
# 23          23  1142207115697803264
# 24          24  1142207105430147074
# 25          25  1142207036920385536
# 26          26  1142206874147856391
# 27          27  1142206864098320384
# 28          28  1142206828740263937
# 29          29  1142206795500400640
# ..         ...                  ...
# 70          70  1142208303726022656
# 71          71  1142208289922531336
# 72          72  1142208289805099009
# 73          73  1142208265910136832
# 74          74  1142208259752976384
# 75          75  1142208249850204161
# 76          76  1142208249233584129
# 77          77  1142208238882099201
# 78          78  1142208233039376391
# 79          79  1142208230518644737
# 80          80  1142208227481923585
# 81          81  1142208214504759296
# 82          82  1142208202215481346
# 83          83  1142208189666136064
# 84          84  1142208188340670464
# 85          85  1142208177448071168
# 86          86  1142208143465897984
# 87          87  1142208125753286664
# 88          88  1142208124788584448
# 89          89  1142208111320666112
# 90          90  1142208109735239680
# 91          91  1142208107495469056
# 92          92  1142208099220164609
# 93          93  1142208087245430785
# 94          94  1142208070552096770
# 95          95  1142208065883611138
# 96          96  1142208042827694080
# 97          97  1142208028692877313
# 98          98  1142208022200094720
# 99          99  1142208009579499520
#
#                                                  text  \
# 0                      Nossa putaria é quase um poema
# 1   ManooooKKKKKKKKK apareceu aqueles vídeos de li...
# 2   @felipesimoncini É putaria né ? Aqui no dique ...
# 3   acabei de fazer um Tinder pra minha tia e fale...
# 4   RT @MiiEDB: Queria viver um romance porém esta...
# 5   @jairbolsonaro @EderMauroPA BOTAFOGO QUERENDO ...
# 6   RT @lucilia_ferraz: Minha mãe tá aqui na festa...
# 7   Todo gringo que está disposto a empreender dev...
# 8   Essa bicha de Rosa 100% tentando ser uma mulhe...
# 9   @EderMauroPA BOTAFOGO QUERENDO MUDAR O REGIMEN...
# 10  @LaiilaChan @yoonpkjm Somos todos nenéns safad...
# 11  RT @idkgringa: gal gadot é sempre meu espírito...
# 12  @NaorEduardo O tweeter é feito pra postar merd...
# 13        PUTARIA NA BARREIRA https://t.co/4EWlKxOUGE
# 14  O AUGE EH EU CHAMANDO A GAROTA P FICAR COMIGO ...
# 15  @JoseMedeirosMT @fabiss1072 @SF_Moro @ggreenwa...
# 16                Brt pelos prédio putaria tá frmd💃🎶🎶
# 17  metade de mim é poesia e a outra metade é puta...
# 18  @urreastars será q eh muito difícil ter um amo...
# 19  Eu no meu tt de boa aí do nada uma putaria kkk...
# 20  RT @darthsisith: parece ironia querer viver um...
# 21  RT @stajeon: 🔞🔞🔞🔞 ATENÇÃO 🔞🔞🔞🔞\n\nFesta na cas...
# 22  tem amor, tem carinho, tem atenção... mas pare...
# 23  RT @djwsdaigrejinha: SAIU LANÇAMENTO !!! CONFE...
# 24  @Mendesa74456671 é meio difícil acreditar no a...
# 25  cansado demais pra aguenta filha da putice ain...
# 26  Foi muito bom te encontrar mas é a putaria que...
# 27  Minha amiga namorando, perdi minha amiga da pu...
# 28  RT @soaresaraujoo: mt dificil querer um amor n...
# 29                               fogo no cu e putaria
# ..                                                ...
# 70  @lovelxlisa pq ele é uma bosta? me simpatizo t...
# 71              meu deus só tem horário bosta pra mib
# 72  @lemarc_s Realmente uma bosta as 2\nChega a ir...
# 73  @suibian_A Tem gente perguntando como doar pra...
# 74  @tdbem Eu tenho tanto nojo desse homem que o d...
# 75               mais na bosta que eu, só duas de mim
# 76  Quando a porra do servidor de merda porco do c...
# 77       Nossa gente, que bosta que esta esse feriado
# 78  @luizvidaum @monica2js @RachelSherazade @JoelP...
# 79  @marcofeliciano Parabéns , pastor! Ficou a tua...
# 80  RT @BeyFAlice: Sem @NicoleBahls nessa edição, ...
# 81  foi só pra manter os seguidores w eu tinha lá ...
# 82  RT @BeyFAlice: Sem @NicoleBahls nessa edição, ...
# 83  essa bosta tá me cansando, só chama quando que...
# 84  será msm q esses dois carinhas são dotados de ...
# 85  RT @moonqueenxRass: o ciclo da vida é\n\n     ...
# 86              Um BOSTA MAIS https://t.co/opgwck8X5k
# 87  RT @CarolGo2018: toda guria já teve o cabelo l...
# 88                          Como o whats ta uma bosta
# 89  @senadorhumberto @redeTVT Umberto Bosta só pov...
# 90  @senadorhumberto @SF_Moro Acho melhor vc renun...
# 91          @moonbytae Gabriela com G de grande bosta
# 92  RT @BeyFAlice: Sem @NicoleBahls nessa edição, ...
# 93  Será que to errada em desejar que tivesse aula...
# 94                 Que bosta! https://t.co/zdixnlsIpW
# 95  RT @danigbera: signos que vão ficar juntos:\n\...
# 96  @PereiraAdolpho Sua imbecilidade está escancar...
# 97  RT @bruninkk: us guri é o caralho teu merda ma...
# 98  @_JonathanFons_ Isso é o retrato da imbecilida...
# 99  @reinaldoazevedo @folha Falou pouco mas falou ...
#
#                                             normalize   tag
# 0                      nossa putaria é quase um poema  hate
# 1   manok apareceu aqueles vídeos de ligações do b...  hate
# 2   é putaria né aqui no dique é frenquentar nos a...  hate
# 3   acabei de fazer um tinder pra minha tia e fale...     -
# 4   queria viver um romance porém estamos no sécul...     -
# 5   botafogo querendo mudar o regimento para se pe...     -
# 6   minha mãe tá aqui na festa dela falando putari...     -
# 7   todo gringo que está disposto a emprender deve...     -
# 8   essa bicha de rosa 10 tentando ser uma mulher ...  hate
# 9   botafogo querendo mudar o regimento para se pe...     -
# 10  somos todos nenéns safados por dentro alguns m...  hate
# 11  gal gadot é sempre meu espírito animal tentand...  hate
# 12  o tweter é feito pra postar merda expor suas f...  hate
# 13               putaria na bareira htpstco4ewlkxouge     -
# 14  o auge eh eu chamando a garota p ficar comigo ...     -
# 15  botafogo querendo mudar o regimento para se pe...     -
# 16                 brt pelos prédio putaria tá frmd💃🎶     -
# 17  metade de mim é poesia e a outra metade é puta...  hate
# 18  será q eh muito difícil ter um amor no século ...  hate
# 19   eu no meu t de boa aí do nada uma putaria k scrr     -
# 20  parece ironia querer viver um amor no século d...     -
# 21  🔞 atenção 🔞 festa na casa dos blods hoje com d...     -
# 22  tem amor tem carinho tem atenção mas parece q ...  hate
# 23  saiu lançamento confere la que esa ta pesada 🔥...     -
# 24  é meio difícil acreditar no amor durante o séc...  hate
# 25  cansado demais pra aguenta filha da putice ain...     -
# 26  foi muito bom te encontrar mas é a putaria que...  hate
# 27  minha amiga namorando perdi minha amiga da put...     -
# 28     mt dificil querer um amor no século da putaria     -
# 29                               fogo no cu e putaria     -
# ..                                                ...   ...
# 70    pq ele é uma bosta me simpatizo tanto com ele k  hate
# 71              meu deus só tem horário bosta pra mib     -
# 72           realmente uma bosta as 2 chega a irritar     -
# 73  tem gente perguntando como doar pra love or ha...  hate
# 74  eu tenho tanto nojo desse homem que o dia que ...     -
# 75                mais na bosta que eu só duas de mim     -
# 76  quando a porra do servidor de merda porco do c...  hate
# 77        nossa gente que bosta que esta esse feriado     -
# 78  ô mongolóide meu comentário foi em relação a c...  hate
# 79         parabéns pastor ficou a tua cara uma bosta     -
# 80  sem nessa edição o powercouplebrasil estaria u...     -
# 81  foi só pra manter os seguidores w eu tinha lá ...  hate
# 82  sem nessa edição o powercouplebrasil estaria u...     -
# 83  essa bosta tá me cansando só chama quando quer...     -
# 84  será msm q esses dois carinhas são dotados de ...  hate
# 85  o ciclo da vida é nascer se apaixonar por livr...     -
# 86                    um bosta mais htpstcoopgwck8x5k     -
# 87  toda guria já teve o cabelo lindo grande e sau...  hate
# 88                          como o whats ta uma bosta     -
# 89  umberto bosta só povinho do partido das trevas...  hate
# 90  acho melhor vc renunciar humberto bosta vivemo...     -
# 91                     gabriela com g de grande bosta     -
# 92  sem nessa edição o powercouplebrasil estaria u...     -
# 93  será que to errada em desejar que tivesse aula...  hate
# 94                        que bosta htpstcozdixnlsipw     -
# 95  signos que vão ficar juntos larga de ser troux...  hate
# 96  sua imbecilidade está escancarada na sua face ...     -
# 97  us guri é o caralho teu merda mais de 20 ano n...  hate
# 98  isso é o retrato da imbecilidade esse bosta nã...  hate
# 99  falou pouco mas falou bosta como sempre htpstc...     -
#
# [100 rows x 5 columns]

# %%
dataframe.groupby('tag').count()
# Out:
#       Unnamed: 0     id   text  normalize
# tag
# -          47880  47880  47880      47880
# hate       37301  37301  37301      37301

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
train_reviews = dataframe['normalize'].values.tolist()
train_classes = []

for value in dataframe['tag'].values.tolist():
    train_classes.append(0 if value == 'hate' else 1)

transformer = TfidfVectorizer()
transformer.fit(train_reviews)
X = transformer.transform(train_reviews)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier_lr = LogisticRegression(n_jobs=4)
classifier_lr.fit(X, train_classes)
# Out:
# /media/igorecarvalho/Documentos/UFLA/virtualenvs/gcc151_trabfinal_env/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /media/igorecarvalho/Documentos/UFLA/virtualenvs/gcc151_trabfinal_env/lib/python3.5/site-packages/sklearn/linear_model/logistic.py:1544: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 3.
#   " = {}.".format(effective_n_jobs(self.n_jobs)))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=3, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#sentence = "MORTTEEE AOS VIADOS!! bichiiiiiiiiiiiiiiiiiiiinhas"
sentence = "bicinha escroto, precisa morrer"
instance = transformer.transform([normalize(sentence)])
classifier_lr.predict(instance)
# Out:
# array([1])
